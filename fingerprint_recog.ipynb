# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import glob, os

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.7.4

# %%
from tensorflow.keras import layers, models
import tensorflow as tf

# %%
import keras
from keras import layers
from keras.models import Model, load_model
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from imgaug import augmenters as iaa

import random

# %%
import sys
print(sys.executable)
# Out:
# D:\G\python\fingerprint\ven\Scripts\python.exe

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_real.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_real.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_real.npy to dataset/x_real.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_easy.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_easy.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_easy.npy to dataset/x_easy.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_medium.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_medium.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_medium.npy to dataset/x_medium.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_hard.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_hard.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_hard.npy to dataset/x_hard.npz successfully.

# %%
re=np.load('dataset/x_real.npy')
re.shape
import cv2

resized_images = []
for img in re:
    resized_img = cv2.resize(img, (90, 90))
    resized_images.append(resized_img)

resized_images = np.array(resized_images)

# %%
x_real_resized = resized_images[..., np.newaxis]

# %%
np.save('dataset/x_real_reshaped.npy', x_real_resized)

# %%
import numpy as np
re_reshaped=np.load('dataset/x_real_reshaped.npy')
re_reshaped.shape
# Out:
# (6000, 90, 90, 1)

# %%
med=np.load('dataset/x_medium.npy')
re.shape
import cv2

resized_images = []
for img in med:
    resized_img = cv2.resize(img, (90, 90))
    resized_images.append(resized_img)

resized_images = np.array(resized_images)
x_real_resized = resized_images[..., np.newaxis]
np.save('dataset/x_medium_reshaped.npy', x_real_resized)

# %%
import numpy as np
re_reshaped=np.load('dataset/x_medium_reshaped.npy')
re_reshaped.shape
# Out:
# (17067, 90, 90, 1)

# %%
hard=np.load('dataset/x_hard.npy')
hard.shape
# Out:
# (14272, 96, 96)

# %%
hard=np.load('dataset/x_hard.npy')
hard.shape
import cv2

resized_images = []
for img in hard:
    resized_img = cv2.resize(img, (90, 90))
    resized_images.append(resized_img)

resized_images = np.array(resized_images)
x_real_resized = resized_images[..., np.newaxis]
np.save('dataset/x_hard_reshaped.npy', x_real_resized)

# %%
import numpy as np
re_reshaped=np.load('dataset/x_hard_reshaped.npy')
re_reshaped.shape
# Out:
# (14272, 90, 90, 1)

# %%
easy=np.load('dataset/x_easy.npy')
easy.shape
import cv2

resized_images = []
for img in easy:
    resized_img = cv2.resize(img, (90, 90))
    resized_images.append(resized_img)

resized_images = np.array(resized_images)
x_real_resized = resized_images[..., np.newaxis]
np.save('dataset/x_easy_reshaped.npy', x_real_resized)

# %%
import numpy as np
re_reshaped=np.load('dataset/x_easy_reshaped.npy')
re_reshaped.shape
# Out:
# (17931, 90, 90, 1)

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_easy_reshaped.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_easy_reshaped.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_easy_reshaped.npy to dataset/x_easy_reshaped.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_hard_reshaped.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_hard_reshaped.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_hard_reshaped.npy to dataset/x_hard_reshaped.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_real_reshaped.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_real_reshaped.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_real_reshaped.npy to dataset/x_real_reshaped.npz successfully.

# %%
import numpy as np

# Step 1: Load .npy file
npy_file = 'dataset/x_medium_reshaped.npy'
data = np.load(npy_file)

# Step 2: Save as .npz file
npz_file = 'dataset/x_medium_reshaped.npz'
np.savez(npz_file, data=data)

print(f"Converted {npy_file} to {npz_file} successfully.")
# Out:
# Converted dataset/x_medium_reshaped.npy to dataset/x_medium_reshaped.npz successfully.

# %% [markdown]
# # LOAD DATASET

# %%
x_real = np.load('dataset/x_real_reshaped.npz')['data']
y_real = np.load('dataset/y_real.npy')
x_easy = np.load('dataset/x_easy_reshaped.npz')['data']
y_easy = np.load('dataset/y_easy.npy')
x_medium = np.load('dataset/x_medium_reshaped.npz')['data']
y_medium = np.load('dataset/y_medium.npy')
x_hard = np.load('dataset/x_hard_reshaped.npz')['data']
y_hard = np.load('dataset/y_hard.npy')

print(x_real.shape, y_real.shape)

plt.figure(figsize=(15, 10))
plt.subplot(1, 4, 1)
plt.title(y_real[0])
plt.imshow(x_real[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 2)
plt.title(y_easy[0])
plt.imshow(x_easy[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 3)
plt.title(y_medium[0])
plt.imshow(x_medium[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 4)
plt.title(y_hard[0])
plt.imshow(x_hard[0].squeeze(), cmap='gray')
# Out:
# (6000, 90, 90, 1) (6000, 4)
# D:\G\python\fingerprint\ven\lib\site-packages\matplotlib\text.py:1241: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # Train Test split

# %%
x_data = np.concatenate([x_easy, x_medium, x_hard], axis=0)
label_data = np.concatenate([y_easy, y_medium, y_hard], axis=0)

x_train, x_val, label_train, label_val = train_test_split(x_data, label_data, test_size=0.1)

print(x_data.shape, label_data.shape)
print(x_train.shape, label_train.shape)
print(x_val.shape, label_val.shape)
# Out:
# (49270, 90, 90, 1) (49270, 4)
# (44343, 90, 90, 1) (44343, 4)
# (4927, 90, 90, 1) (4927, 4)

# %% [markdown]
# # preview augmentation

# %%
augs = [x_data[40000]] * 9

seq = iaa.Sequential([
    # blur images with a sigma of 0 to 0.5
    iaa.GaussianBlur(sigma=(0, 0.5)),
    iaa.Affine(
        # scale images to 90-110% of their size, individually per axis
        scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
        # translate by -10 to +10 percent (per axis)
        translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
        # rotate by -30 to +30 degrees
        rotate=(-30, 30),
        # use nearest neighbour or bilinear interpolation (fast)
        order=[0, 1],
        # if mode is constant, use a cval between 0 and 255
        cval=255
    )
], random_order=True)

augs = seq.augment_images(augs)

plt.figure(figsize=(16, 6))
plt.subplot(2, 5, 1)
plt.title('original')
plt.imshow(x_data[40000].squeeze(), cmap='gray')
for i, aug in enumerate(augs):
    plt.subplot(2, 5, i+2)
    plt.title('aug %02d' % int(i+1))
    plt.imshow(aug.squeeze(), cmap='gray')

# %% [markdown]
# # Make Label Dictionary Lookup Table

# %%
label_real_dict = {}

for i, y in enumerate(y_real):
    key = y.astype(str)
    key = ''.join(key).zfill(6)

    label_real_dict[key] = i

# %% [markdown]
# # Data Generartor

# %%
from tensorflow.keras.utils import Sequence
class DataGenerator(Sequence):
    def __init__(self, x, label, x_real, label_real_dict, batch_size=32, shuffle=True):
        'Initialization'
        self.x = x
        self.label = label
        self.x_real = x_real
        self.label_real_dict = label_real_dict
        
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.x) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        x1_batch = self.x[index*self.batch_size:(index+1)*self.batch_size]
        label_batch = self.label[index*self.batch_size:(index+1)*self.batch_size]
        
        x2_batch = np.empty((self.batch_size, 90, 90, 1), dtype=np.float32)
        y_batch = np.zeros((self.batch_size, 1), dtype=np.float32)
         # augmentation
        if self.shuffle:
            seq = iaa.Sequential([
                iaa.GaussianBlur(sigma=(0, 0.5)),
                iaa.Affine(
                    scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
                    translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
                    rotate=(-30, 30),
                    order=[0, 1],
                    cval=255
                )
            ], random_order=True)

            x1_batch = seq.augment_images(x1_batch)
        
        # pick matched images(label 1.0) and unmatched images(label 0.0) and put together in batch
        # matched images must be all same, [subject_id(3), gender(1), left_right(1), finger(1)], e.g) 034010
        for i, l in enumerate(label_batch):
            match_key = l.astype(str)
            match_key = ''.join(match_key).zfill(6)

            if random.random() > 0.5:
                # put matched image
                x2_batch[i] = self.x_real[self.label_real_dict[match_key]]
                y_batch[i] = 1.
            else:
                # put unmatched image
                while True:
                    unmatch_key, unmatch_idx = random.choice(list(self.label_real_dict.items()))

                    if unmatch_key != match_key:
                        break
                x2_batch[i] = self.x_real[unmatch_idx]
                y_batch[i] = 0.

        return [x1_batch.astype(np.float32) / 255., x2_batch.astype(np.float32) / 255.], y_batch

    def on_epoch_end(self):
        if self.shuffle == True:
            self.x, self.label = shuffle(self.x, self.label)

# %%
train_gen = DataGenerator(x_train, label_train, x_real, label_real_dict, shuffle=True)
val_gen = DataGenerator(x_val, label_val, x_real, label_real_dict, shuffle=False)

# %% [markdown]
# # Create Model

# %%
x1 = layers.Input(shape=(90, 90, 1))
x2 = layers.Input(shape=(90, 90, 1))

# share weights both inputs
inputs = layers.Input(shape=(90, 90, 1))

feature = layers.Conv2D(32, kernel_size=3, padding='same', activation='relu')(inputs)
feature = layers.MaxPooling2D(pool_size=2)(feature)

feature = layers.Conv2D(32, kernel_size=3, padding='same', activation='relu')(feature)
feature = layers.MaxPooling2D(pool_size=2)(feature)

feature_model = Model(inputs=inputs, outputs=feature)

# 2 feature models that sharing weights
x1_net = feature_model(x1)
x2_net = feature_model(x2)

# subtract features
net = layers.Subtract()([x1_net, x2_net])

net = layers.Conv2D(32, kernel_size=3, padding='same', activation='relu')(net)
net = layers.MaxPooling2D(pool_size=2)(net)

net = layers.Flatten()(net)

net = layers.Dense(64, activation='relu')(net)

net = layers.Dense(1, activation='sigmoid')(net)

model = Model(inputs=[x1, x2], outputs=net)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 90, 90, 1)]  0           []
#
#  input_2 (InputLayer)           [(None, 90, 90, 1)]  0           []
#
#  model (Functional)             (None, 22, 22, 32)   9568        ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  subtract (Subtract)            (None, 22, 22, 32)   0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  conv2d_2 (Conv2D)              (None, 22, 22, 32)   9248        ['subtract[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 11, 11, 32)  0           ['conv2d_2[0][0]']
#
#  flatten (Flatten)              (None, 3872)         0           ['max_pooling2d_2[0][0]']
#
# ...

# %% [markdown]
# # Train

# %% [markdown]
# # Evaluation

# %%
import os

model_dir = 'D:/G/python/fingerprint/ven/my_model'

# Check if the directory exists
if os.path.exists(model_dir):
    print(f"Directory '{model_dir}' exists.")
else:
    print(f"Directory '{model_dir}' does not exist.")

# List the contents of the directory
for root, dirs, files in os.walk(model_dir):
    print(f"Root: {root}")
    print(f"Directories: {dirs}")
    print(f"Files: {files}")
# Out:
# Directory 'D:/G/python/fingerprint/ven/my_model' exists.
# Root: D:/G/python/fingerprint/ven/my_model
# Directories: ['assets', 'variables']
# Files: ['fingerprint.pb', 'keras_metadata.pb', 'saved_model.pb']
# Root: D:/G/python/fingerprint/ven/my_model\assets
# Directories: []
# Files: []
# Root: D:/G/python/fingerprint/ven/my_model\variables
# Directories: []
# Files: ['variables.data-00000-of-00001', 'variables.index']

# %%
import os

# Print the current working directory
print(os.getcwd())
# Out:
# D:\G\python\fingerprint\ven

# %%
import tensorflow as tf
import os

# Get the absolute path to avoid any path-related issues
model_dir = os.path.abspath('my_model')
# Set experimental I/O device options
options = tf.saved_model.LoadOptions(
    experimental_io_device='/job:localhost'
)
model = tf.saved_model.load(model_dir, options=options)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\G\python\fingerprint\ven\lib\site-packages\tensorflow\python\framework\ops.py:4098, in Graph._get_op_def(self, type)
#    4097 try:
# -> 4098   return self._op_def_cache[type]
#    4099 except KeyError:
#
# KeyError: 'DisableCopyOnRead'
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# File D:\G\python\fingerprint\ven\lib\site-packages\tensorflow\python\saved_model\load.py:938, in load_internal(export_dir, tags, options, loader_cls, filters)
#     937 try:
# --> 938   loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     939                       ckpt_options, options, filters)
#     940 except errors.NotFoundError as err:
#
# ...

# %%
from keras.models import load_model
import os

# Get the absolute path to avoid any path-related issues
model_dir = os.path.abspath('my_model')

# Load the model
model = load_model(model_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 8
#       5 model_dir = os.path.abspath('my_model')
#       7 # Load the model
# ----> 8 model = load_model(model_dir)
#
# File D:\G\python\fingerprint\ven\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File D:\G\python\fingerprint\ven\lib\site-packages\tensorflow\python\saved_model\load.py:941, in load_internal(export_dir, tags, options, loader_cls, filters)
#     938   loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     939                       ckpt_options, options, filters)
# ...

# %%
# new user fingerprint input
random_idx = random.randint(0, len(x_val))

random_img = x_val[random_idx]
random_label = label_val[random_idx]

seq = iaa.Sequential([
    iaa.GaussianBlur(sigma=(0, 0.5)),
    iaa.Affine(
        scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
        translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
        rotate=(-30, 30),
        order=[0, 1],
        cval=255
    )
], random_order=True)

random_img = seq.augment_image(random_img).reshape((1, 90, 90, 1)).astype(np.float32) / 255.

# matched image
match_key = random_label.astype(str)
match_key = ''.join(match_key).zfill(6)

rx = x_real[label_real_dict[match_key]].reshape((1, 90, 90, 1)).astype(np.float32) / 255.
ry = y_real[label_real_dict[match_key]]

pred_rx = model.predict([random_img, rx])

# unmatched image
unmatch_key, unmatch_idx = random.choice(list(label_real_dict.items()))

ux = x_real[unmatch_idx].reshape((1, 90, 90, 1)).astype(np.float32) / 255.
uy = y_real[unmatch_idx]

pred_ux = model.predict([random_img, ux])

plt.figure(figsize=(8, 4))
plt.subplot(1, 3, 1)
plt.title('Input: %s' %random_label)
plt.imshow(random_img.squeeze(), cmap='gray')
plt.subplot(1, 3, 2)
plt.title('O: %.02f, %s' % (pred_rx, ry))
plt.imshow(rx.squeeze(), cmap='gray')
plt.subplot(1, 3, 3)
plt.title('X: %.02f, %s' % (pred_ux, uy))
plt.imshow(ux.squeeze(), cmap='gray')
